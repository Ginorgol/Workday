# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")



import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

from sklearn.model_selection import GridSearchCV

import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

from tqdm import tqdm
import os

from bs4 import BeautifulSoup

from xgboost import XGBClassifier

# %%
df = pd.read_csv('./largest.csv', encoding='latin')

# %%
df.head()
# Out:
#                            Assigned_Group                 ClosureProductName  \
# 0                           ITOPS-PLAN-L1             GLOVIA DAO/ASL (32681)
# 1                          ITOPS-TOOLS-L1                    ORACLE DATABASE
# 2  ITOPS-IEO ITRC Monitoring Network-Data                NETWORK DATA DEVICE
# 3      ITOPS-IEO ITRC Monitoring Database  Oracle Enterprise Manager (32850)
# 4      ITOPS-IEO ITRC Monitoring Database                SmartPrice (391181)
#
#                      IncidentProduct  \
# 0             GLOVIA DAO/ASL (32681)
# 1                    ORACLE DATABASE
# 2                NETWORK DATA DEVICE
# 3  Oracle Enterprise Manager (32850)
# 4                SmartPrice (391181)
#
#                                          Description  \
# 0  #Relief - Order missing relief in Glovia - Cos...
# 1  Request to remove the below Mentioned targets ...
# 2         Network Outage_-_         _-_LCJ1MFGETL2K2
# 3  Target Availability_-_Status - / -ausfloem2db0...
# 4  Target Availability_-_Status - / -ausplsmphadb...
#
#                         Custom_category
# 0                                L1 App
# 1                                L1 App
# 2  IT Ops L1 Monitoring Response Center
# 3  IT Ops L1 Monitoring Response Center
# 4  IT Ops L1 Monitoring Response Center

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                 Assigned_Group  \
# 0                                ITOPS-PLAN-L1
# 1                               ITOPS-TOOLS-L1
# 2       ITOPS-IEO ITRC Monitoring Network-Data
# 3           ITOPS-IEO ITRC Monitoring Database
# 4           ITOPS-IEO ITRC Monitoring Database
# 5                               ITOPS-SALES-L1
# 6                             ITRC-UserApps-L1
# 7                         ITOPS-MONITORING-DFS
# 8                        ITOPS-MONITORING-SHIP
# 9       ITOPS-IEO ITRC Monitoring Network-Data
# 10                ITOPS-FIRSTRESPONSE-DATABASE
# 11          ITOPS-IEO ITRC Monitoring Database
# 12                  ITOPS-FIRSTRESPONSE-SERVER
# 13                        ITOPS-MONITORING-GSD
# 14                  ITOPS-FIRSTRESPONSE-SERVER
# 15                              ITOPS-SALES-L1
# 16                      ITOPS-MONITORING-TOOLS
# 17                  ITOPS-FIRSTRESPONSE-SERVER
# 18                      ITOPS-MONITORING-SALES
# 19                  ITOPS-FIRSTRESPONSE-SERVER
# 20                  ITOPS-FIRSTRESPONSE-SERVER
# 21                    ITOPS-MONITORING-EMS-OPE
# 22                       ITOPS-MONITORING-CORP
# 23                      ITOPS-MONITORING-SALES
# 24                  ITOPS-ORDER-MGMT-LEGACY-L1
# 25                        ITOPS-MONITORING-GSD
# 26          ITOPS-IEO ITRC Monitoring Database
# 27                       ITOPS-MONITORING-PLAN
# 28                      ITOPS-MONITORING-TOOLS
# 29      ITOPS-IEO ITRC Monitoring Network-Data
# ...                                        ...
# 156894                    ITOPS-CALL-CENTER-L1
# 156895                        ITRC-UserApps-L1
# 156896                            ITOPS-GII-L1
# 156897             ITOPS-FIRSTRESPONSE-STORAGE
# 156898                       ITOPS-SERVICES-L1
# 156899              ITOPS-ORDER-MGMT-LEGACY-L1
# 156900                           ITOPS-SHIP-L1
# 156901                  ITOPS-MONITORING-SALES
# 156902                  ITOPS-MONITORING-SALES
# 156903                       ITOPS-SERVICES-L1
# 156904        ITOPS-IEO ITRC Monitoring Server
# 156905                           ITOPS-SHIP-L1
# 156906                          ITOPS-BUILD-L1
# 156907            ITOPS-FIRSTRESPONSE-DATABASE
# 156908      ITOPS-IEO ITRC Monitoring Database
# 156909              ITOPS-FIRSTRESPONSE-SERVER
# 156910                  ITOPS-MONITORING-TOOLS
# 156911            ITOPS-FIRSTRESPONSE-DATABASE
# 156912                           ITOPS-SHIP-L1
# 156913                  ITOPS-MONITORING-SALES
# 156914                      ITOPS-LICENSING-L1
# 156915                          ITOPS-BUILD-L1
# 156916                  ITOPS-MONITORING-SALES
# 156917                          ITOPS-TOOLS-L1
# 156918                          ITOPS-SALES-L1
# 156919                  ITOPS-MONITORING-SALES
# 156920                  ITOPS-MONITORING-SALES
# 156921                  ITOPS-MONITORING-TOOLS
# 156922        ITOPS-IEO ITRC Monitoring Server
# 156923                ITOPS-MONITORING-EMS-OPE
#
#                                      ClosureProductName  \
# 0                                GLOVIA DAO/ASL (32681)
# 1                                       ORACLE DATABASE
# 2                                   NETWORK DATA DEVICE
# 3                     Oracle Enterprise Manager (32850)
# 4                                   SmartPrice (391181)
# 5                       LegacyEcomm - Myaccount (34523)
# 6                                     RSA SECURID TOKEN
# 7                                     CMS/BRAMS (32338)
# 8       Oracle Transportation Management (OTM) (416055)
# 9                                          CISCO ROUTER
# 10                                             DATABASE
# 11                                        OMEGA (34653)
# 12                                            POWEREDGE
# 13                   BUSINESS INTEGRATION LAYER (32822)
# 14                                         INTEL SERVER
# 15                             SFDC - Dell Main (31930)
# 16                                       CITRIX (32734)
# 17                                  WINDOWS 2008 SERVER
# 18                        DellStar Offline AMER (32650)
# 19                                  WINDOWS 2008 SERVER
# 20                                            POWEREDGE
# 21              GLOBAL PRODUCT CATALOG SERVICES (32255)
# 22                          HR Analytics (HRA) (454095)
# 23                         eSupport - Articles (481275)
# 24                                         DOMS (34502)
# 25                       Qfiniti Dell Services (558667)
# 26                                      DFS BMS (32296)
# 27                               GLOVIA DAO/ASL (32681)
# 28        Microsoft System Center Orchestrator (348778)
# 29                                  NETWORK DATA DEVICE
# ...                                                 ...
# 156894                                   AVAYA IP AGENT
# 156895                                      Syncplicity
# 156896                                GII - APJ (36268)
# 156897                              STORAGE - SAN - CML
# 156898                                    DELTA (36122)
# 156899                                          CA DOMS
# 156900                             DragonFx DAO (32090)
# 156901                    DELL SCHEDULER CLIENT (32606)
# 156902                           ARB SELECT APP (32637)
# 156903               BUSINESS INTEGRATION LAYER (32822)
# 156904                                        POWEREDGE
# 156905                             DragonFX APJ (32214)
# 156906                            MINTELLIGENCE (33970)
# 156907                                         DATABASE
# 156908                                MIAS EMEA (32440)
# 156909                               Alternative Access
# 156910                Oracle Enterprise Manager (32850)
# 156911                             MICROSOFT SQL SERVER
# 156912                        LogisticsServices (31939)
# 156913                           ARB SELECT APP (32637)
# 156914                     DIGITAL FULFILLMENT (242975)
# 156915                         MES Dynamics AX (249340)
# 156916                       Online Site Tools (529751)
# 156917                              ServiceNow (391696)
# 156918            DSA - Dell Sales Application (903974)
# 156919                         SALESFORCE (EMC) - Sales
# 156920                                   Octane (32274)
# 156921                                    OMEGA (34653)
# 156922                                        POWEREDGE
# 156923          Global Product Config Services (783617)
#
#                                         IncidentProduct  \
# 0                                GLOVIA DAO/ASL (32681)
# 1                                       ORACLE DATABASE
# 2                                   NETWORK DATA DEVICE
# 3                     Oracle Enterprise Manager (32850)
# 4                                   SmartPrice (391181)
# 5                       LegacyEcomm - Myaccount (34523)
# 6                                     RSA SECURID TOKEN
# 7                                     CMS/BRAMS (32338)
# 8       Oracle Transportation Management (OTM) (416055)
# 9                                          CISCO ROUTER
# 10                                             DATABASE
# 11                                        OMEGA (34653)
# 12                                            POWEREDGE
# 13                   BUSINESS INTEGRATION LAYER (32822)
# 14                                         INTEL SERVER
# 15                             SFDC - Dell Main (31930)
# 16                                       CITRIX (32734)
# 17                                  WINDOWS 2008 SERVER
# 18                        DellStar Offline AMER (32650)
# 19                                  WINDOWS 2008 SERVER
# 20                                        DELTA (36122)
# 21              GLOBAL PRODUCT CATALOG SERVICES (32255)
# 22                          HR Analytics (HRA) (454095)
# 23                         eSupport - Articles (481275)
# 24                                         DOMS (34502)
# 25                       Qfiniti Dell Services (558667)
# 26                                      DFS BMS (32296)
# 27                               GLOVIA DAO/ASL (32681)
# 28        Microsoft System Center Orchestrator (348778)
# 29                                  NETWORK DATA DEVICE
# ...                                                 ...
# 156894                                   AVAYA IP AGENT
# 156895                                      Syncplicity
# 156896                                GII - APJ (36268)
# 156897                              STORAGE - SAN - CML
# 156898                                    DELTA (36122)
# 156899                                          CA DOMS
# 156900                             DragonFx DAO (32090)
# 156901                    DELL SCHEDULER CLIENT (32606)
# 156902                           ARB SELECT APP (32637)
# 156903               BUSINESS INTEGRATION LAYER (32822)
# 156904                                        POWEREDGE
# 156905                             DragonFX APJ (32214)
# 156906                            MINTELLIGENCE (33970)
# 156907                                         DATABASE
# 156908                                MIAS EMEA (32440)
# 156909                               Alternative Access
# 156910                Oracle Enterprise Manager (32850)
# 156911                             MICROSOFT SQL SERVER
# 156912                        LogisticsServices (31939)
# 156913                           ARB SELECT APP (32637)
# 156914                     DIGITAL FULFILLMENT (242975)
# 156915                         MES Dynamics AX (249340)
# 156916                       Online Site Tools (529751)
# 156917                              ServiceNow (391696)
# 156918            DSA - Dell Sales Application (903974)
# 156919                         SALESFORCE (EMC) - Sales
# 156920                                   Octane (32274)
# 156921                                    OMEGA (34653)
# 156922                                        POWEREDGE
# 156923          Global Product Config Services (783617)
#
#                                               Description  \
# 0       #Relief - Order missing relief in Glovia - Cos...
# 1       Request to remove the below Mentioned targets ...
# 2              Network Outage_-_         _-_LCJ1MFGETL2K2
# 3       Target Availability_-_Status - / -ausfloem2db0...
# 4       Target Availability_-_Status - / -ausplsmphadb...
# 5                                         (2bp)My Account
# 6                                               RSA issue
# 7       Workload Automation Batch: DFS_DBC_PLP_EXCEPTI...
# 8       2018-02-06_23:04 COUNT= 1_-_EMEA 211 Not sent ...
# 9       [CHG126932] BGP Peer Not Established_-_(peer t...
# 10                            unable to login to database
# 11      Oracle WebLogic Server_-_server_servlet_jsp:se...
# 12      [TASK] Storage drives missing on multiple KUL ...
# 13      [MANUAL] [Application] URL Down_-_Simple URL_h...
# 14                             VCPPWDSS02 is inaccessible
# 15                   Please revert PR003204603 back to 0%
# 16      Dell.ITGlobal.SMSAgent.Service.Consecutive.sam...
# 17      [TASK] Patching windows Sunday 5am till 9am MY...
# 18      [MANUAL] [Application] URL Down_-_Simple URL_h...
# 19      PGSPSQL01.AMER.DELL.COM failed to RDP through ...
# 20      Low free memory on on ausplsposbapp01.us.dell....
# 21      [MANUAL] [Application][Windows] CPU Usage_-_CP...
# 22      [MANUAL] [Application] URL Down_-_Simple URL_h...
# 23      Tealeaf event above threshold_-_EventID: 9999 ...
# 24      1 Order (1 Unit) not downloading to OFS/EPITOM...
# 25      eTalk_Recording Level AUSPWQOS07 KB0930940 Qfi...
# 26      Dell SQLServer 2016 AlwaysOn Failover 1480_-_M...
# 27      Workload Automation Batch: GLDAO_EOM_START_MQS...
# 28      [MANUAL] [Application] URL Down_-_Simple URL_h...
# 29               Network Outage_-_         _-_C4DRACacc09
# ...                                                   ...
# 156894                                  call not answered
# 156895                     Unable to log into Syncplicity
# 156896                                          Gii issue
# 156897  [XMN] SR#973065296 - XMNCML201 - Disk 110 [08-...
# 156898  Hi team order#343645817 and order# 343645825 a...
# 156899                        I need doms passwword reset
# 156900  BRH1 - DRAGON - Orders must be resent through ...
# 156901  Config - Replicate Prebuild Flush - EMEA PREMI...
# 156902  Page Failure: Critical_-_External Synthetic Mo...
# 156903      [IN-BR] Dellserv Maint Issues - probably Java
# 156904  [TASK] Memory_-_alertMemoryDevice_-_ausmegadev...
# 156905                                MISSING CTO MN FEED
# 156906  I was given access to the tool, But not able t...
# 156907           Listner down in AUSULHLXDB21.us.dell.com
# 156908  Automatic Storage Management_-_Status - / -+AS...
# 156909      [ACCESS] 117 access setup for service account
# 156910  [MANUAL] Agent_-_Status - / -ausflm2gemfdb02.u...
# 156911  I lost my connectivity to u4vmdwssrsapp01.aus....
# 156912  Order 661890554 is stuck at status (SC) can yo...
# 156913  Page Failure: Critical_-_External Synthetic Mo...
# 156914              uploaded key is not a PRODUCTION Type
# 156915  Blue ship label not printing for order: 105178787
# 156916  [MANUAL] [Application] URL Down_-_Simple URL_h...
# 156917  Please assist me pull a complete list of IT Tr...
# 156918               DSA wont load quotes or place orders
# 156919  Workload Automation Batch: SFDC_RAD_ACCOUNT_UP...
# 156920  Workload Automation Batch: RTD_DM_OBM Job ende...
# 156921  Target Availability_-_Status - / -ausdlqtcdb02...
# 156922  [TASK] Storage Software_-_alertPCIDevice_-_idr...
# 156923  [MANUAL] [Application] URL Down_-_Simple URL_h...
#
#                              Custom_category
# 0                                     L1 App
# 1                                     L1 App
# 2       IT Ops L1 Monitoring Response Center
# 3       IT Ops L1 Monitoring Response Center
# 4       IT Ops L1 Monitoring Response Center
# 5                                     L1 App
# 6                                     L1 App
# 7       IT Ops L1 Monitoring Response Center
# 8       IT Ops L1 Monitoring Response Center
# 9       IT Ops L1 Monitoring Response Center
# 10                                  L1 Infra
# 11      IT Ops L1 Monitoring Response Center
# 12                                  L1 Infra
# 13      IT Ops L1 Monitoring Response Center
# 14                                  L1 Infra
# 15                                    L1 App
# 16      IT Ops L1 Monitoring Response Center
# 17                                  L1 Infra
# 18      IT Ops L1 Monitoring Response Center
# 19                                  L1 Infra
# 20                                  L1 Infra
# 21      IT Ops L1 Monitoring Response Center
# 22      IT Ops L1 Monitoring Response Center
# 23      IT Ops L1 Monitoring Response Center
# 24                                  L1 Infra
# 25      IT Ops L1 Monitoring Response Center
# 26      IT Ops L1 Monitoring Response Center
# 27      IT Ops L1 Monitoring Response Center
# 28      IT Ops L1 Monitoring Response Center
# 29      IT Ops L1 Monitoring Response Center
# ...                                      ...
# 156894                                L1 App
# 156895                                L1 App
# 156896                                L1 App
# 156897                              L1 Infra
# 156898                                L1 App
# 156899                              L1 Infra
# 156900                                L1 App
# 156901  IT Ops L1 Monitoring Response Center
# 156902  IT Ops L1 Monitoring Response Center
# 156903                                L1 App
# 156904  IT Ops L1 Monitoring Response Center
# 156905                                L1 App
# 156906                                L1 App
# 156907                              L1 Infra
# 156908  IT Ops L1 Monitoring Response Center
# 156909                              L1 Infra
# 156910  IT Ops L1 Monitoring Response Center
# 156911                              L1 Infra
# 156912                                L1 App
# 156913  IT Ops L1 Monitoring Response Center
# 156914                                L1 App
# 156915                                L1 App
# 156916  IT Ops L1 Monitoring Response Center
# 156917                                L1 App
# 156918                                L1 App
# 156919  IT Ops L1 Monitoring Response Center
# 156920  IT Ops L1 Monitoring Response Center
# 156921  IT Ops L1 Monitoring Response Center
# 156922  IT Ops L1 Monitoring Response Center
# 156923  IT Ops L1 Monitoring Response Center
#
# [156351 rows x 5 columns]

# %%
# https://stackoverflow.com/a/47091490/4084039
import re

def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# https://gist.github.com/sebleier/554280
# we are removing the words from the stop words list: 'no', 'nor', 'not'
# <br /><br /> ==> after the above steps, we are getting "br br"
# we are including them into stop words list
# instead of <br /> if we have <br/> these tags would have revmoved in the 1st step

stopwords= set(['br', 'the', 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't"])

# Combining all the above stundents

# %%
short_desc = []
# tqdm is for printing the status bar
for sentance in tqdm(df['Description'].values):
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    short_desc.append(sentance.strip())

df['cleaned'] = short_desc
# Out:
# 100%|██████████| 156351/156351 [00:58<00:00, 2664.52it/s]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df['cleaned'], df['Assigned_Group'],
                                                    shuffle=False, test_size=0.2)

# %%
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
tf_idf_vect.fit(X_train)
print("some sample features(unique words in the corpus)",tf_idf_vect.get_feature_names()[0:10])
print('='*50)

X_train_tf_idf = tf_idf_vect.transform(X_train)
print("the type of count vectorizer ",type(X_train_tf_idf))
print("the shape of out text TFIDF vectorizer ",X_train_tf_idf.get_shape())
print("the number of unique words including both unigrams and bigrams ", X_train_tf_idf.get_shape()[1])

X_test_tfidf = tf_idf_vect.transform(X_test)
# Out:
# some sample features(unique words in the corpus) ['aa', 'aa cc', 'aa config', 'aaci', 'aaci dont', 'aalnskdkaeavk', 'aaplication', 'aarons', 'aarthi', 'aarthi ravivarman']
# ==================================================
# the type of count vectorizer  <class 'scipy.sparse.csr.csr_matrix'>
# the shape of out text TFIDF vectorizer  (125080, 95280)
# the number of unique words including both unigrams and bigrams  95280

# %%
with open('tf_idf_vect_assigned_group_150k.pickle', 'wb') as f:
    pickle.dump(tf_idf_vect, f, pickle.HIGHEST_PROTOCOL)

# %%
clf = XGBClassifier()
clf.fit(X_train_tf_idf, Y_train)
clf.score(X_test_tfidf, Y_test)

# %%
with open('clf_assigned_group_150k.pickle', 'wb') as f:
    pickle.dump(clf, f, pickle.HIGHEST_PROTOCOL)

# %%
review_text = ["mail is not working"]

cleaned_review_text = []
for sentance in tqdm(review_text):
    sentance = re.sub(r"http\S+", "", sentance)
    sentance = BeautifulSoup(sentance, 'lxml').get_text()
    sentance = decontracted(sentance)
    sentance = re.sub("\S*\d\S*", "", sentance).strip()
    sentance = re.sub('[^A-Za-z]+', ' ', sentance)
    # https://gist.github.com/sebleier/554280
    sentance = ' '.join(e.lower() for e in sentance.split() if e.lower() not in stopwords)
    cleaned_review_text.append(sentance.strip())
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1095.69it/s]

# %%
z = tf_idf_vect.transform(cleaned_review_text)

# %%
clf.predict(z)
# Out:
# array(['ITOPS-SALES-L1'], dtype=object)

# %%
Y_train.value_counts()
# Out:
# ITOPS-MONITORING-SALES                     18286
# ITOPS-IEO ITRC Monitoring Database         12045
# ITOPS-SALES-L1                              7268
# ITOPS-IEO ITRC Monitoring Server            6747
# ITOPS-FIRSTRESPONSE-SERVER                  6286
# ITOPS-MONITORING-TOOLS                      5953
# ITRC-UserApps-L1                            4882
# ITOPS-MONITORING-GSD                        4624
# ITOPS-SERVICES-L1                           4214
# ITOPS-MONITORING-SHIP                       3834
# ITOPS-MONITORING-PLAN                       3515
# ITOPS-IEO ITRC Monitoring Network-Data      3422
# ITOPS-MONITORING-EMS-OPE                    3330
# ITOPS-SHIP-L1                               3296
# ITOPS-FIRSTRESPONSE-DATABASE                2870
# ITOPS-OMEGA-L1                              2752
# ITOPS-MONITORING-OM                         2506
# ITOPS-ORDER-MGMT-LEGACY-L1                  2224
# ITOPS-GII-L1                                1998
# ITOPS-OES-L1                                1956
# ITOPS-MONITORING-DFS                        1656
# ITOPS-CALL-CENTER-L1                        1611
# ITOPS-PLAN-L1                               1568
# ITOPS-CORP-L1                               1504
# ITOPS-BURN-L1                               1462
# ITOPS-TOOLS-L1                              1356
# ITOPS-IEO ITRC Monitoring Backup            1341
# ITOPS-FIRSTRESPONSE-STORAGE                  975
# ITOPS-FINANCE-L1                             882
# ITOPS-LICENSING-L1                           869
#                                            ...
# ITOPS-PRODUCT-L1                             576
# ITOPS-MONITORING-EMS-DBI                     547
# ITOPS-MONITORING-FIT-TTR                     533
# ITOPS-MONITORING-CORP                        444
# ITOPS-MONITORING-EMS-IMGMT                   441
# ITOPS-IEO ITRC Monitoring Network-Voice      438
# ITOPS-FIT-TTR-L1                             412
# ITOPS-MONITORING-EMS-DFS                     395
# ITOPS-MONITORING-BUILD                       362
# ITOPS-FIRSTRESPONSE-NETWORK-DATA             355
# ITOPS-FIRSTRESPONSE-NETWORK-VOICE            338
# ITOPS-PGIT-L1                                310
# ITOPS-MONITORING-MIDDLEWARE                  290
# ITOPS-DFS-L1                                 271
# ITOPS-MONITORING-EMS-SERVICES                255
# OpsIT Event Management & Analytics           248
# ITOPS-MONITORING-OES                         227
# ITOPS-MONITORING-LICENSING                   220
# ITOPS-MONITORING-BURN                        218
# ITOPS-MONITORING-FINANCE                     216
# ITOPS-MONITORING-GO                          206
# ITOPS-MONITORING-EMS-GCCS                    174
# ITOPS-MONITORING-PGIT                        143
# ITOPS-OCI-L1                                  71
# ITOPS-MONITORING-EMS-SOA                      59
# ITOPS-MONITORING-NOVORA                       34
# ITOPS-CRM-EMEA-L1                             20
# ITOPS-MONITORING-COINS                         7
# ITOPS-MONITORING-EMS-TOOLS                     4
# ITOPS-IEO ITRC Monitoring Storage              4
# Name: Assigned_Group, Length: 63, dtype: int64
